# %%
# !pip install -q nltk
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %% [markdown]
# **Experiment 3.1:** Write a Python program to perform stemming using the Porter Stemmer. Apply stemming to the following words. Display the original words and their stems.
#
# playing, played, plays, studies, studying, connected, connection, computers

# %%
from nltk.stem import PorterStemmer

# Create stemmer
stemmer = PorterStemmer()

# List of words
words = ["playing", "played", "plays", "studies", "studying", "connected", "connection", "computers"]

# Apply stemming
print("Word -> Stem")
for word in words:
    print(word, "->", stemmer.stem(word))
# Out:
# Word -> Stem
# playing -> play
# played -> play
# plays -> play
# studies -> studi
# studying -> studi
# connected -> connect
# connection -> connect
# computers -> comput

# %% [markdown]
# **Experiment 3.2:** Write a Python program to perform lemmatization on a given input words:
#
# cats, dogs, running, runs, ran, studies, studying, better, children, mice, went, ate, leaves, caring

# %%
from nltk.stem import WordNetLemmatizer

# Create lemmatizer
lemmatizer = WordNetLemmatizer()

# List of words
words = ["cats", "dogs", "running", "runs", "ran", "studies", "studying",
         "better", "children", "mice", "went", "ate", "leaves", "caring"]

# Apply lemmatization
print("Word -> Lemma")
for word in words:
    print(word, "->", lemmatizer.lemmatize(word))
# Out:
# Word -> Lemma
# cats -> cat
# dogs -> dog
# running -> running
# runs -> run
# ran -> ran
# studies -> study
# studying -> studying
# better -> better
# children -> child
# mice -> mouse
# went -> went
# ate -> ate
# leaves -> leaf
# caring -> caring

# %% [markdown]
# **Experiment 3.3:** Write a Python program using Regular Expressions (Regex) to extract and process the following information from a text: Email addresses, URLs, Mobile numbers, Hashtags, Mentions
#
# **Input Text:**
# Welcome to the Natural Language Processing workshop! For more information, visit https://www.nlpworkshop.com or www.python.org. You can contact the coordinator at nlpworkshop@gmail.com or support@python.org. For registration, call +91-9876543210 or 9123456789. Follow us on social media @NLPWorkshop and @PythonLearner. Share your experience using #NLP, #Python, and #MachineLearning. You can also visit https://github.com/NLPWorkshop for the

# %%
import re

text = """Welcome to the Natural Language Processing workshop! For more information, visit https://www.nlpworkshop.com or www.python.org. You can contact the coordinator at nlpworkshop@gmail.com or support@python.org. For registration, call +91-9876543210 or 9123456789. Follow us on social media @NLPWorkshop and @PythonLearner. Share your experience using #NLP, #Python, and #MachineLearning. You can also visit https://github.com/NLPWorkshop for the latest updates."""

print(text)
# Out:
# Welcome to the Natural Language Processing workshop! For more information, visit https://www.nlpworkshop.com or www.python.org. You can contact the coordinator at nlpworkshop@gmail.com or support@python.org. For registration, call +91-9876543210 or 9123456789. Follow us on social media @NLPWorkshop and @PythonLearner. Share your experience using #NLP, #Python, and #MachineLearning. You can also visit https://github.com/NLPWorkshop for the latest updates.

# %%
emails = re.findall(r'\S+@\S+', text)
print("Emails:", emails)
# Out:
# Emails: ['nlpworkshop@gmail.com', 'support@python.org.']

# %%
urls = re.findall(r'(?:https?://\S+|www\.\S+)', text)
print("URLs:", urls)
# Out:
# URLs: ['https://www.nlpworkshop.com', 'www.python.org.', 'https://github.com/NLPWorkshop']

# %%
mobile_numbers = re.findall(r'(?:\+91-?)?\d{10}', text)
print("Mobile Numbers:", mobile_numbers)
# Out:
# Mobile Numbers: ['+91-9876543210', '9123456789']

# %%
hashtags = re.findall(r'#\w+', text)
print("Hashtags:", hashtags)
# Out:
# Hashtags: ['#NLP', '#Python', '#MachineLearning']

# %%
mentions = re.findall(r'@\w+', text)
print("Mentions:", mentions)
# Out:
# Mentions: ['@gmail', '@python', '@NLPWorkshop', '@PythonLearner']
